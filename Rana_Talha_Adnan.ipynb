# %% [markdown]
# # Data Preprocessing Steps

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
color = sns.color_palette()

import numpy as np
import pandas as pd

# %% [markdown]
# # 1: Reading Data

# %%
data = pd.read_csv('Car details v3.csv')

data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data.head(2)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats
# 0       190Nm@ 2000rpm    5.0
# 1  250Nm@ 1500-2500rpm    5.0

# %%
data.head(30)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %% [markdown]
# ## Last rows:
# 1. DataFrame
# 2. show array  (default).

# %%
data.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power                     torque  seats
# 8123  82.85 bhp           113.7Nm@ 4000rpm    5.0
# ...

# %% [markdown]
# ### Dimensions:
# 2.  Shows the size in the format of (rows, columns).
# ### Quick info:
# 4.  Used to quickly understand the overall structure of the dataset.

# %%
data.shape
# Out:
# (8128, 13)

# %% [markdown]
# 1. Last 20 rows to display (default behavior).

# %%
data.tail(20)
# Out:
#                                               name  year  selling_price  \
# 8108                      Kia Seltos HTX Plus AT D  2019        1575000
# 8109      Ford Freestyle Titanium Plus Diesel BSIV  2018         750000
# 8110                            Maruti Celerio VXI  2017         425000
# 8111                    Toyota Etios Cross 1.4L GD  2014         425000
# 8112      Ford Freestyle Titanium Plus Diesel BSIV  2018         746000
# 8113  Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV  2010         425000
# 8114                               Maruti Alto LXi  2011         200000
# 8115                                 Maruti 800 AC  1997          40000
# 8116                    Maruti Alto K10 VXI Airbag  2017         340000
# 8117                        Maruti Swift Dzire VDI  2015         625000
# 8118                             Hyundai i20 Magna  2013         380000
# 8119                   Maruti Wagon R LXI Optional  2017         360000
# ...

# %% [markdown]
# ### Random rows:
#
# 2.  Used to select random rows from the dataset.
#
# ### Custom size:
#
# 2.  You can specify how many rows you want using the n parameter

# %%
data.sample()
# Out:
#                                                   name  year  selling_price  \
# 6902  Mahindra Bolero 2011-2019 DI NON AC BS III White  2011         250000
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# 6902     100000  Diesel  Individual       Manual  Second Owner  15.96 kmpl
#
#        engine max_power               torque  seats
# 6902  2523 CC    63 bhp  180Nm@ 1440-1500rpm    9.0

# %%
data.sample(30)
# Out:
#                                              name  year  selling_price  \
# 7271                Maruti Alto K10 2010-2014 VXI  2012         235000
# 1624               Tata Indica Vista Aqua 1.4 TDI  2011         248000
# 5673                         Toyota Etios Liva GD  2012         275000
# 4715         Skoda Octavia RS 1.8 Turbo Petrol MT  2006         100000
# 2373                      Ford Figo 1.5D Trend MT  2017         500000
# 3276                         Maruti Ciaz ZDi Plus  2015         600000
# 6512       Ford EcoSport 1.5 Petrol Titanium BSIV  2019         885000
# 1324                 Maruti Eeco 5 Seater AC BSIV  2017         330000
# 7767                       Mahindra XUV500 W6 2WD  2011         475000
# 7436                       Mahindra XUV500 W6 2WD  2012         800000
# 853              Hyundai EON 1.0 Kappa Magna Plus  2015         204999
# 7205                     Honda City 2017-2020 GXi  2008         185000
# ...

# %% [markdown]
# ###  Provides a quick :
#
# 2.   summary of the dataset (like column names, types, non-null values).
#
# ### Data types:
#
# 4.  Shows the data type (e.g., int, float, object) of each column.
#
#  ### Missing values:
#
# 6.  Helps in identifying missing or null values easily.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %% [markdown]
# 1. ###  Count, Min, Max:
# Shows the count, min, max, and quartiles of the data.
#
# 2. ###  Data insight:
#   Useful for getting a quick overview

# %%
data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %% [markdown]
# # Data cleaning
# 1. Handling Missing Values
# 2. Imputation: Filling missing values with mean.

# %%
data.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %% [markdown]
# 1. data.select_dtypes
#
#   1. Selects columns from the DataFrame data that have numeric data types (like int or float).
#
# 3. pd.DataFrame(numeric_cols): Converts the selected numeric columns into a new DataFrame nm.
#
# 4. nm.head(2): Displays the first 2 rows of the nm DataFrame.

# %%
numeric_cols = data.select_dtypes(include=[np.number])
nm = pd.DataFrame(numeric_cols)
nm.head(2)
# Out:
#    year  selling_price  km_driven  seats
# 0  2014         450000     145500    5.0
# 1  2014         370000     120000    5.0

# %% [markdown]
# 1. Selects non-numeric columns.
# 2.  Converts non-numeric columns into a new DataFrame
# 3.  Displays the first 2 rows

# %%
non_numeric_cols = data.select_dtypes(exclude=[np.number])
non_nm = pd.DataFrame(non_numeric_cols)
non_nm.head(2)
# Out:
#                            name    fuel seller_type transmission  \
# 0        Maruti Swift Dzire VDI  Diesel  Individual       Manual
# 1  Skoda Rapid 1.5 TDI Ambition  Diesel  Individual       Manual
#
#           owner     mileage   engine   max_power               torque
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp       190Nm@ 2000rpm
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp  250Nm@ 1500-2500rpm

# %%
import pandas as pd
import numpy as np

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

numeric_cols.fillna(numeric_cols.mean(), inplace=True)  


data1 = pd.concat([numeric_cols, non_numeric_cols], axis=1)

missing_values = data1.isnull().sum()
print(missing_values)
# Out:
# year               0
# selling_price      0
# km_driven          0
# seats              0
# name               0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# dtype: int64

# %%
data.shape
# Out:
# (8128, 13)

# %% [markdown]
# # Removal: Deleting rows with missing values.

# %%
data = pd.read_csv('Car details v3.csv')
data.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
data.shape
# Out:
# (8128, 13)

# %% [markdown]
# 1. Count missing values:

# %%
data.isnull().sum().sum()
# Out:
# 1100

# %% [markdown]
# 1. Removes all rows with missing (null) values from the DataFrame data.
#
#
#
#
#
# 2. Checks for any remaining missing values in the DataFrame after dropping rows.
#
#    sum() counts the number of missing values per column.
#
#
#
# 3. Prints the count of missing values in each column after the rows are dropped.

# %%
data.dropna(inplace=True)
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
data.shape
# Out:
# (7906, 13)

# %% [markdown]
# # Removing Duplicates

# %%
data = pd.read_csv('Car details v3.csv')
data.shape
# Out:
# (8128, 13)

# %% [markdown]
# 1. Removes all duplicate rows in the DataFrame data.
# 2. Prints the shape of the DataFrame after duplicates are removed

# %%
data.drop_duplicates(inplace=True)
print(data.shape)
# Out:
# (6926, 13)

# %% [markdown]
# 3: Outlier Detection and Removal¶

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('Car details v3.csv')


data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
0.25-1.5*0.5
# Out:
# -0.5

# %%
0.75 + 1.5 * 0.5
# Out:
# 1.5

# %% [markdown]
# 1. Select numeric columns from the dataset.
#
# 2. Calculate IQR (Q3 - Q1).
#
# 3. Filter out rows where any numeric value is an outlier (below Q1 - 1.5×IQR or above Q3 + 1.5×IQR).
#
# 4. Plot boxplots before removing outliers for visual comparison.

# %%
numeric_cols = data.select_dtypes(include=[np.number])

Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1



data_cleaned = data[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]


plt.figure(figsize=(20, 6))


plt.subplot(1, 2, 1)
numeric_cols.boxplot()
plt.title("Before Outlier Removal")



plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Before Plot: Shows boxplots of numeric data with outliers.
#
# 2. Outlier Removal: Uses the IQR method to filter out rows with outliers.
#
# 3. After Plot: Shows boxplots of numeric data after outliers are removed.

# %%
plt.figure(figsize=(20, 6))


plt.subplot(1, 2, 2)
data.select_dtypes(include=[np.number]).boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
data_cleaned.shape
# Out:
# (5926, 13)

# %%
data_cleaned.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# # Data Transformation
# Key Differences
# Range of Values:
#
# Normalization: Values are scaled to a fixed range, typically [0, 1]. Standardization: Values are rescaled to have a mean of 0 and a standard deviation of 1. Effect on Distribution:
#
# # Normalization:
# Compresses or stretches the data to fit within the specified range, potentially altering the original distribution. Standardization: Preserves the shape of the original distribution but changes the scale. Use Cases:
#
# Normalization: Suitable for distance-based algorithms, like k-nearest neighbors and neural networks. Standardization: Suitable for algorithms that assume a normal distribution, like linear regression and logistic regression.
#
# Normalization/Standardization
# Normalization Definition: Normalization rescales the data to a fixed range, typically [0, 1] or [-1, 1].

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler


data = pd.read_csv('Car details v3.csv')


numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])


scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)


scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)


scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)


print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (8128, 13)
#
# ************************************************************
#        year  selling_price  km_driven  seats                          name  \
# 0  0.837838       0.042126   0.061640   0.25        Maruti Swift Dzire VDI
# 1  0.837838       0.034102   0.050837   0.25  Skoda Rapid 1.5 TDI Ambition
# 2  0.621622       0.012839   0.059310   0.25      Honda City 2017-2020 EXi
# 3  0.729730       0.019559   0.053803   0.25     Hyundai i20 Sportz Diesel
# 4  0.648649       0.010030   0.050837   0.25        Maruti Swift VXI BSIII
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# 1  Diesel  Individual       Manual  Second Owner  21.14 kmpl  1498 CC
# 2  Petrol  Individual       Manual   Third Owner   17.7 kmpl  1497 CC
# 3  Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4  Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
#
# ...

# %% [markdown]
# # Standardization
#  Standardization rescales the data so that it has a mean of 0 and a standard deviation of 1.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('Car details v3.csv')


numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])


scaler = StandardScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)


scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)


scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)


print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (8128, 13)
#
# ************************************************************
#        year  selling_price  km_driven     seats                          name  \
# 0  0.048464      -0.233529   1.338363 -0.434297        Maruti Swift Dzire VDI
# 1  0.048464      -0.332759   0.887411 -0.434297  Skoda Rapid 1.5 TDI Ambition
# 2 -1.929775      -0.595720   1.241098 -0.434297      Honda City 2017-2020 EXi
# 3 -0.940656      -0.512615   1.011202 -0.434297     Hyundai i20 Sportz Diesel
# 4 -1.682495      -0.630451   0.887411 -0.434297        Maruti Swift VXI BSIII
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# 1  Diesel  Individual       Manual  Second Owner  21.14 kmpl  1498 CC
# 2  Petrol  Individual       Manual   Third Owner   17.7 kmpl  1497 CC
# 3  Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4  Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
#
# ...

# %% [markdown]
# # 5: One-Hot Encoding¶

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('Car details v3.csv')
data.head(2)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats
# 0       190Nm@ 2000rpm    5.0
# 1  250Nm@ 1500-2500rpm    5.0

# %%
data["name"].unique()
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Tata Nexon 1.5 Revotorq XT',
#        'Ford Freestyle Titanium Plus Diesel BSIV',
#        'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV'], dtype=object)

# %% [markdown]
# 1. cat_features: collects the names of all categorical columns (dtype 'O').
#
# 1. pd.get_dummies(...): converts those categorical columns into one-hot encoded columns.
#
# 3. data1: stores the transformed categorical features as numeric.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('Car details v3.csv')


cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']


data1 = pd.get_dummies(cat_features)
data1
# Out:
#    engine   fuel  max_power  mileage   name  owner  seller_type  torque  \
# 0   False  False      False    False   True  False        False   False
# 1   False   True      False    False  False  False        False   False
# 2   False  False      False    False  False  False         True   False
# 3   False  False      False    False  False  False        False   False
# 4   False  False      False    False  False   True        False   False
# 5   False  False      False     True  False  False        False   False
# 6    True  False      False    False  False  False        False   False
# 7   False  False       True    False  False  False        False   False
# 8   False  False      False    False  False  False        False    True
#
#    transmission
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   engine        9 non-null      bool
#  1   fuel          9 non-null      bool
#  2   max_power     9 non-null      bool
#  3   mileage       9 non-null      bool
#  4   name          9 non-null      bool
#  5   owner         9 non-null      bool
#  6   seller_type   9 non-null      bool
#  7   torque        9 non-null      bool
#  8   transmission  9 non-null      bool
# dtypes: bool(9)
# memory usage: 213.0 bytes

# %% [markdown]
# #### This means these are the features in your dataset that contain non-numeric (categorical) values, and you might want to encode them

# %%
cat_features
# Out:
# ['name',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner',
#  'mileage',
#  'engine',
#  'max_power',
#  'torque']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('Car details v3.csv')

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

data1 = pd.get_dummies(data, columns=cat_features)

scaled_data = pd.concat([data, data1], axis=1)

print(scaled_data.shape)
print()
print('*' * 70)

scaled_data.head()
# Out:
# (8128, 3366)
#
# **********************************************************************
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine  ...  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC  ...
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  ...
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC  ...
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC  ...
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC  ...
#
# ...

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
scaled_data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine',
#        ...
#        'torque_96.1Nm@ 3000rpm', 'torque_96Nm@ 2500rpm',
#        'torque_96Nm@ 3000rpm', 'torque_96Nm@ 3500rpm',
#        'torque_98Nm@ 1600-3000rpm', 'torque_99.04Nm@ 4500rpm',
#        'torque_99.07Nm@ 4500rpm', 'torque_99.1Nm@ 4500rpm',
#        'torque_99.8Nm@ 2700rpm', 'torque_99Nm@ 4500rpm'],
#       dtype='object', length=3366)

# %%
data1.head()
# Out:
#    year  selling_price  km_driven  seats  name_Ambassador CLASSIC 1500 DSL AC  \
# 0  2014         450000     145500    5.0                                False
# 1  2014         370000     120000    5.0                                False
# 2  2006         158000     140000    5.0                                False
# 3  2010         225000     127000    5.0                                False
# 4  2007         130000     120000    5.0                                False
#
#    name_Ambassador Classic 2000 DSZ AC PS  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    name_Ambassador Grand 1500 DSZ BSIII  name_Ambassador Grand 2000 DSZ PW CL  \
# 0                                 False                                 False
# 1                                 False                                 False
# ...

# %% [markdown]
# # 6: Data Reduction

# %% [markdown]
# ## Dimensionality Reduction
# -
# PCA (Principal Component Analysis)

# %%
scaled_data.shape
# Out:
# (8128, 3366)

# %% [markdown]
# ### One-Hot Encode Categorical Features
# → Converts categorical features into binary numeric columns using pd.get_dummies.
#
# ### Standardize Numeric Features
# → Uses StandardScaler to normalize numeric columns (mean = 0, std = 1).
#
# ### Apply PCA
# → Reduces data to 15 principal components to compress feature space while retaining variance.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


data = pd.read_csv('Car details v3.csv')


data.fillna(data.mean(numeric_only=True), inplace=True)


cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']


data = pd.get_dummies(data, columns=cat_features)


scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)


pca = PCA(n_components=15)
data_pca = pca.fit_transform(data)


print(data_pca.shape)
print(data_pca[:5]) 

###########################



plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[numeric_features[0]], data[numeric_features[1]], alpha=0.5)
plt.title('Original Data')
plt.xlabel(numeric_features[0])
plt.ylabel(numeric_features[1])


pca = PCA(n_components=15)  
data_pca = pca.fit_transform(data)


plt.subplot(1, 2, 2)
plt.scatter(data_pca[:, 0], data_pca[:, 1], alpha=0.5)
plt.title('PCA Transformed Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

plt.tight_layout()
plt.show()
# Out:
# (8128, 15)
# [[-7.11986880e-01  3.17177222e-01  6.35253633e-01  1.56004349e+00
#   -3.68585340e-01 -4.82714084e-01  1.86325886e-01  1.24061406e+00
#    2.78461874e-03  8.43717839e-02 -2.65097248e-02 -5.26337628e-01
#    1.35335981e-01  1.00786659e-01 -1.10310510e-02]
#  [-8.21775544e-01  9.65553048e-02  5.24319422e-01  7.89148480e-01
#   -3.94963727e-01  8.72723720e-01 -1.35648142e-01 -5.44632163e-01
#    1.17802638e-02 -2.16073014e-02 -4.44575704e-02  1.12437139e-01
#   -1.61013744e-01  2.29099831e-02  7.28766619e-02]
#  [-2.18351246e+00 -7.44420623e-01  9.34372970e-01 -5.44746174e-01
#    6.01442748e-01 -3.05390309e-01  1.84716306e-01  1.35870958e-01
#   -2.14184109e-02 -9.47455620e-02  2.41873145e-02  5.33311269e-01
#    8.15734712e-01 -2.11669039e-01  4.95137885e-02]
#  [-1.26909782e+00 -5.45468037e-02  6.27535973e-01  5.54770579e-01
#   -2.56093039e-01 -7.45772742e-01  1.97777903e-01 -5.60010675e-01
#    1.88089794e-01  3.31089592e-02  8.72165741e-02 -2.61319735e-01
# ...

# %%
type(data_pca)
# Out:
# numpy.ndarray

# %%
data_pca.ndim
# Out:
# 2

# %%
data_pca.shape
# Out:
# (8128, 15)

# %% [markdown]
# # 7: Handling Imbalanced Data
#
# - Resampling Techniques
# - Oversampling

# %%
data = pd.read_csv('Car details v3.csv')

data.engine.value_counts(True)
# Out:
# engine
# 1248 CC    0.128620
# 1197 CC    0.105223
# 998 CC     0.057291
# 796 CC     0.056153
# 2179 CC    0.049197
#              ...
# 2835 CC    0.000126
# 1489 CC    0.000126
# 1422 CC    0.000126
# 2496 CC    0.000126
# 1950 CC    0.000126
# Name: proportion, Length: 121, dtype: float64

# %%
data.shape
# Out:
# (8128, 13)

# %% [markdown]
# Undersampling
# -

# %%
data = pd.read_csv('Car details v3.csv')

# %%
data.shape
# Out:
# (8128, 13)

# %% [markdown]
# ### Converted mileage,
# engine, max_power to numeric.
#
# ### Dropped
#     torque (too inconsistent).
#
# ### Filled missing values.
#
# One-hot encoded categorical columns.
#
# ### Scaled
#     numeric features.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
data = pd.read_csv('Car details v3.csv')
data.fillna(data.mean(numeric_only=True), inplace=True)

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']
data = pd.get_dummies(data, columns=cat_features)


scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)
if data['engine'].dtype != 'int64' and data['engine|'].dtype != 'bool':
    data['engine'] = (data['engine'] > 0.5).astype(int)


X = data.drop(columns=['engine']) 
y = data['engine'] 


if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)


smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)


data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['engine'])], axis=1)
data_resampled.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'engine'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 17
#      15 scaler = StandardScaler()
# ...

# %%
data.engine.value_counts(True)
# Out:
# engine
# 1248 CC    0.128620
# 1197 CC    0.105223
# 998 CC     0.057291
# 796 CC     0.056153
# 2179 CC    0.049197
#              ...
# 2835 CC    0.000126
# 1489 CC    0.000126
# 1422 CC    0.000126
# 2496 CC    0.000126
# 1950 CC    0.000126
# Name: proportion, Length: 121, dtype: float64

# %% [markdown]
# # Target Encoder

# %%
import pandas as pd
from category_encoders import TargetEncoder

# Example dataset
data = {'engine': ['AC', 'AC PS'], 'Target': [1, 0,]}
df = pd.DataFrame(data)

target_encoder = TargetEncoder(cols=['engine'])
target_encoded = target_encoder.fit_transform(df['engine'], df['target'])
print(target_encoded)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 import pandas as pd
# ----> 2 from category_encoders import TargetEncoder
#       4 # Example dataset
#       5 data = {'engine': ['AC', 'AC PS'], 'Target': [1, 0,]}
#
# ModuleNotFoundError: No module named 'category_encoders'

# %% [markdown]
# ### Imports necessary tools:
#
# train_test_split from sklearn.model_selection helps split data into training and testing sets.
#
# ### Loads data:
#
# pd.read_csv('Car details v3.csv') loads a CSV file into a DataFrame (data).
#
# ### Prepares data:
#
# X contains all columns except 'engine' (features).
#
# y is the 'engine' column (target variable).
#
# ### Splits data:
#
# train_test_split splits X and y into training and testing sets (70% training, 30% testing), with a random seed set for reproducibility.

# %% [markdown]
# 8: Splitting Data

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv('Car details v3.csv')

X = data.drop('engine', axis=1)
y = data['engine']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5689, 12), (2439, 12), (5689,), (2439,))
